# %%
import numpy as np
import matplotlib as plt

# %%
points = [
    [1, 1, 1],
    [-1, -1, 1],
    [2, 2, 1],
    [-2, -2, 1],
    [-1, 1, 1],
    [1, -1, 1]
]
points = np.array(points)
labels = np.array([-1, -1, 1, -1, 1, 1])

# %%
def batch_perceptron(w, iteration=0):
    
    iteration += 1
    print("At iteration {0} working with w = {1}".format(iteration, w))
    if iteration > 100:
        return (0, 0, 0)
    
    errors = []
    error_label_real = []
    n = 0.3
    
    # Check for errors
    for ind, point in enumerate(points):
        if np.dot(w, point)*labels[ind] < 0:
            errors.append(point)
            error_label_real.append(labels[ind])
    # In case of no errors
    if len(errors) < 0:
        return w
    print('Errors = ' + str(errors), end='\n\n')
    
    errors = np.array(errors)
    # Updating the w
    for ind, error in enumerate(errors):
        w = w + n*(error_label_real[ind]*2)*error
    
    return batch_perceptron(w, iteration=iteration)

# %%
batch_perceptron(np.array((1, 0, 0)), iteration=0)
# Out:
# At iteration 1 working with w = [1 0 0]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 2 working with w = [-0.2  0.   0. ]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 3 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 4 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 5 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 6 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 7 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 8 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 9 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 10 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 11 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 12 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 13 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 14 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 15 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 16 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 17 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 18 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 19 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 20 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 21 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 22 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 23 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 24 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 25 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 26 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 27 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 28 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 29 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 30 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 31 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 32 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 33 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 34 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 35 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 36 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 37 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 38 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 39 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 40 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 41 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 42 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 43 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 44 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 45 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 46 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 47 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 48 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 49 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 50 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 51 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 52 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 53 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 54 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 55 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 56 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 57 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 58 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 59 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 60 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 61 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 62 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 63 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 64 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 65 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 66 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 67 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 68 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 69 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 70 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 71 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 72 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 73 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 74 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 75 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 76 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 77 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 78 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 79 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 80 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 81 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 82 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 83 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 84 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 85 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 86 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 87 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 88 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 89 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 90 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 91 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 92 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 93 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 94 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 95 working with w = [2.2 1.2 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 96 working with w = [1.  1.2 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 97 working with w = [ 1.00000000e+00 -2.22044605e-16  0.00000000e+00]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 98 working with w = [-2.00000000e-01 -2.22044605e-16  0.00000000e+00]
# Errors = [array([-1, -1,  1]), array([2, 2, 1]), array([-2, -2,  1]), array([ 1, -1,  1])]
#
# At iteration 99 working with w = [3.4 2.4 0. ]
# Errors = [array([1, 1, 1]), array([-1,  1,  1])]
#
# At iteration 100 working with w = [2.2 2.4 0. ]
# Errors = [array([1, 1, 1]), array([ 1, -1,  1])]
#
# At iteration 101 working with w = [2.2 1.2 0. ]
# (0, 0, 0)
